# %%
def hangman():
    word="palpable"
    validletters="abcdefghijklmnopqrstuvwxyz"
    turns=5
    guessmade=""
    while len(word)>0:
        main=""
        missed=0
        for letter in word:
            if letter in guessmade:
                main=main + letter
            else:
                main= main + "_" + " "

        if main==word:
            print(main)
            print("you win")
            break

        print("guess the word:",main)
        guess=input()

        if guess in validletters:
            guessmade=guessmade + guess
        else:
           print("enter a valid character ")
           guess=input()

        if guess not in word:
            turns=turns-1
            if turns==4:
                print(" 4 turns left ")
                print("   O   ")
            if turns==3:
                print(" 3 turns left ")
                print("   O   ")
                print("   |   ")
                print("  / \  ")
            if turns==2:
                print(" 2 turns left ")
                print("   O   ")
                print("  \|/  ")
                print("  / \  ")
            if turns==1:
                print(" 1 turns left ")
                print("   O   ")
                print("  \|/  ")
                print("  / \  ")
            if turns==0:
                print(" YOU LOSE")
                print("   O_| ")
                print("  \|/  ")
                print("  / \  ")
                print("you could'nt save him")
                break


print("Please enter your name-")
name=input()
print(f"Welcome {name} to Hangman's adventure......I hope you will save him")
print("-----------------------------------------------------------------------")
print("you have 5 turns to save him")
print("----------------------------------------------------------------------")
print("#hint->  Capable of being perceived especially by the sense of touch")

hangman()
# Out:
# Please enter your name-
# garima
# Welcome garima to Hangman's adventure......I hope you will save him
# -----------------------------------------------------------------------
# you have 5 turns to save him
# ----------------------------------------------------------------------
# #hint->  Capable of being perceived especially by the sense of touch
# guess the word: _ _ _ _ _ _ _ _
# p
# guess the word: p_ _ p_ _ _ _
# l
# guess the word: p_ lp_ _ l_
# m
#  4 turns left
#    O
# guess the word: p_ lp_ _ l_
# d
#  3 turns left
#    O
#    |
#   / \
# guess the word: p_ lp_ _ l_
# k
#  2 turns left
#    O
#   \|/
#   / \
# guess the word: p_ lp_ _ l_
# e
# guess the word: p_ lp_ _ le
# t
#  1 turns left
#    O
#   \|/
#   / \
# guess the word: p_ lp_ _ le
# l
# guess the word: p_ lp_ _ le
# w
#  YOU LOSE
#    O_|
#   \|/
#   / \
# you could'nt save him
